# %% [markdown]
# <a href="https://colab.research.google.com/github/kyj098707/Pix2PixTutorial/blob/main/GAN_Generative_Adversarial_Nets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***GAN : Generative Adversarial Nets***

# %%
import torch
import torch.nn as nn

from torchvision import datasets # MNIST 불러오기 용
import torchvision.transforms as transforms # 이미지 변형 용도
from torchvision.utils import save_image # 이미지 저장 후 보여주기 용도

# %% [markdown]
# - 생성자 판별자 모델 정의

# %%
latent_dim = 100

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        # 하나의 블럭에서는 linear -> 배치 정규화 -> LeakyReLU 사용
        def block(input_dim, output_dim, normalize=True):
            layers = [nn.Linear(input_dim, output_dim)]
            if normalize:
                layers.append(nn.BatchNorm1d(output_dim,0.8))
            layers.append(nn.LeakyReLU(0.2,inplace=True))
            return layers

        # 위에서 정의한 블럭을 총 6개를 사용
        self.model = nn.Sequential(
            *block(latent_dim,128,normalize=False),
            *block(128,256),
            *block(256,512),
            *block(512,1024),
            nn.Linear(1024,1*28*28),
            nn.Tanh()
        )
    def forward(self,z):
        img = self.model(z)
        img = img.view(img.size(0),1,28,28)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(1*28*28,512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512,256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256,1),
            nn.Sigmoid(),
        )

    def forward(self, img):
        flattened = img.view(img.size(0),-1)
        output = self.model(flattened)

        return output

# %%
datasets.MNIST
# Out:
# torchvision.datasets.mnist.MNIST

# %%
transforms_train = transforms.Compose([
                                      transforms.Resize(28),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.5],[0.5]),
])

train_dataset = datasets.MNIST(root ="./dataseet", train=True, download=True, transform=transforms_train)
dataloader = torch.utils.data.DataLoader(train_dataset, batch_size = 128, shuffle=True, num_workers=4)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./dataseet/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./dataseet/MNIST/raw/train-images-idx3-ubyte.gz to ./dataseet/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./dataseet/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./dataseet/MNIST/raw/train-labels-idx1-ubyte.gz to ./dataseet/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./dataseet/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./dataseet/MNIST/raw/t10k-images-idx3-ubyte.gz to ./dataseet/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./dataseet/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./dataseet/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./dataseet/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
G = Generator()
D = Discriminator()

# %%
G.cuda()
D.cuda()

adversarial_loss = nn.BCELoss()
adversarial_loss.cuda()

lr = 0.0002

optimizer_G = torch.optim.Adam(G.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(D.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
import time

n_epochs = 200
sample_interval = 2000
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs,_) in enumerate(dataloader):
        real = torch.cuda.FloatTensor(imgs.size(0),1).fill_(1.0)
        fake = torch.cuda.FloatTensor(imgs.size(0),1).fill_(0.0)

        real_imgs = imgs.cuda()

        optimizer_G.zero_grad()
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()

        generated_imgs = G(z)

        g_loss = adversarial_loss(D(generated_imgs),real)

        g_loss.backward()
        optimizer_G.step()

        optimizer_D.zero_grad()
        real_loss = adversarial_loss(D(real_imgs),real)
        fake_loss = adversarial_loss(D(generated_imgs.detach()),fake)
        d_loss = (real_loss + fake_loss)/2

        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(dataloader) + i

        if done % sample_interval == 0:
            save_image(generated_imgs.data[:25], f"{done}.png", nrow=5, normalize=True)

    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [Epoch 0/200] [D loss: 0.448547] [G loss: 1.258205] [Elapsed time: 16.78s]
# [Epoch 1/200] [D loss: 0.523915] [G loss: 0.497543] [Elapsed time: 29.93s]
# [Epoch 2/200] [D loss: 0.354217] [G loss: 2.092202] [Elapsed time: 43.00s]
# [Epoch 3/200] [D loss: 0.431476] [G loss: 0.897236] [Elapsed time: 56.50s]
# [Epoch 4/200] [D loss: 0.243856] [G loss: 3.349501] [Elapsed time: 69.62s]
# [Epoch 5/200] [D loss: 0.235037] [G loss: 2.467269] [Elapsed time: 82.70s]
# [Epoch 6/200] [D loss: 0.339220] [G loss: 1.041686] [Elapsed time: 95.97s]
# [Epoch 7/200] [D loss: 0.329405] [G loss: 2.165486] [Elapsed time: 109.14s]
# [Epoch 8/200] [D loss: 0.524161] [G loss: 1.439835] [Elapsed time: 122.31s]
# [Epoch 9/200] [D loss: 0.376727] [G loss: 0.867682] [Elapsed time: 135.35s]
# [Epoch 10/200] [D loss: 0.576554] [G loss: 4.025119] [Elapsed time: 148.41s]
# [Epoch 11/200] [D loss: 0.391218] [G loss: 2.813426] [Elapsed time: 161.42s]
# [Epoch 12/200] [D loss: 0.248073] [G loss: 1.432431] [Elapsed time: 174.59s]
# [Epoch 13/200] [D loss: 0.188795] [G loss: 1.539240] [Elapsed time: 187.72s]
# [Epoch 14/200] [D loss: 0.139763] [G loss: 2.604321] [Elapsed time: 200.81s]
# [Epoch 15/200] [D loss: 0.319426] [G loss: 0.983380] [Elapsed time: 213.99s]
# [Epoch 16/200] [D loss: 0.183100] [G loss: 1.777401] [Elapsed time: 227.15s]
# [Epoch 17/200] [D loss: 0.105286] [G loss: 4.710832] [Elapsed time: 240.23s]
# [Epoch 18/200] [D loss: 0.336476] [G loss: 0.972366] [Elapsed time: 253.31s]
# [Epoch 19/200] [D loss: 0.121325] [G loss: 2.735343] [Elapsed time: 266.32s]
# [Epoch 20/200] [D loss: 0.354876] [G loss: 4.652031] [Elapsed time: 279.47s]
# [Epoch 21/200] [D loss: 0.268112] [G loss: 3.578672] [Elapsed time: 292.60s]
# [Epoch 22/200] [D loss: 0.120904] [G loss: 3.383461] [Elapsed time: 305.63s]
# [Epoch 23/200] [D loss: 0.173035] [G loss: 2.500903] [Elapsed time: 318.78s]
# [Epoch 24/200] [D loss: 0.131609] [G loss: 4.937819] [Elapsed time: 331.81s]
# [Epoch 25/200] [D loss: 0.190452] [G loss: 2.033446] [Elapsed time: 344.84s]
# [Epoch 26/200] [D loss: 0.170710] [G loss: 1.907499] [Elapsed time: 358.06s]
# [Epoch 27/200] [D loss: 0.339933] [G loss: 4.131928] [Elapsed time: 371.18s]
# [Epoch 28/200] [D loss: 0.063903] [G loss: 3.464873] [Elapsed time: 384.34s]
# [Epoch 29/200] [D loss: 0.155840] [G loss: 2.509958] [Elapsed time: 397.48s]
# [Epoch 30/200] [D loss: 0.140284] [G loss: 2.874704] [Elapsed time: 410.64s]
# [Epoch 31/200] [D loss: 0.168048] [G loss: 1.689356] [Elapsed time: 423.78s]
# [Epoch 32/200] [D loss: 0.218808] [G loss: 2.123101] [Elapsed time: 436.88s]
# [Epoch 33/200] [D loss: 0.121565] [G loss: 2.867779] [Elapsed time: 450.00s]
# [Epoch 34/200] [D loss: 0.225583] [G loss: 2.876667] [Elapsed time: 463.16s]
# [Epoch 35/200] [D loss: 0.089619] [G loss: 2.177223] [Elapsed time: 476.37s]
# [Epoch 36/200] [D loss: 0.118606] [G loss: 2.680196] [Elapsed time: 489.48s]
# [Epoch 37/200] [D loss: 0.236931] [G loss: 5.196027] [Elapsed time: 502.65s]
# [Epoch 38/200] [D loss: 0.110548] [G loss: 2.569582] [Elapsed time: 515.82s]
# [Epoch 39/200] [D loss: 0.248732] [G loss: 1.110394] [Elapsed time: 528.96s]
# [Epoch 40/200] [D loss: 0.410818] [G loss: 0.729631] [Elapsed time: 542.20s]
# [Epoch 41/200] [D loss: 0.136725] [G loss: 3.417864] [Elapsed time: 555.42s]
# [Epoch 42/200] [D loss: 0.149816] [G loss: 2.081436] [Elapsed time: 568.55s]
# [Epoch 43/200] [D loss: 0.155279] [G loss: 2.699356] [Elapsed time: 581.71s]
# [Epoch 44/200] [D loss: 0.219987] [G loss: 2.279956] [Elapsed time: 594.85s]
# [Epoch 45/200] [D loss: 0.111333] [G loss: 3.156023] [Elapsed time: 607.93s]
# [Epoch 46/200] [D loss: 0.111720] [G loss: 3.532141] [Elapsed time: 621.20s]
# [Epoch 47/200] [D loss: 0.168644] [G loss: 2.897800] [Elapsed time: 634.33s]
# [Epoch 48/200] [D loss: 0.438987] [G loss: 0.817224] [Elapsed time: 647.49s]
# [Epoch 49/200] [D loss: 0.142743] [G loss: 2.281538] [Elapsed time: 660.63s]
# [Epoch 50/200] [D loss: 0.171257] [G loss: 2.405724] [Elapsed time: 673.55s]
# [Epoch 51/200] [D loss: 0.143796] [G loss: 2.803149] [Elapsed time: 686.55s]
# [Epoch 52/200] [D loss: 0.103296] [G loss: 2.322838] [Elapsed time: 699.73s]
# [Epoch 53/200] [D loss: 0.360618] [G loss: 1.070327] [Elapsed time: 712.93s]
# [Epoch 54/200] [D loss: 0.141050] [G loss: 4.109348] [Elapsed time: 725.97s]
# [Epoch 55/200] [D loss: 0.254064] [G loss: 4.482676] [Elapsed time: 739.09s]
# [Epoch 56/200] [D loss: 0.119930] [G loss: 2.534687] [Elapsed time: 752.16s]
# [Epoch 57/200] [D loss: 0.232813] [G loss: 3.921799] [Elapsed time: 765.27s]
# [Epoch 58/200] [D loss: 0.146604] [G loss: 2.283913] [Elapsed time: 778.53s]
# [Epoch 59/200] [D loss: 0.665740] [G loss: 5.316256] [Elapsed time: 791.50s]
# [Epoch 60/200] [D loss: 0.155220] [G loss: 2.830704] [Elapsed time: 804.55s]
# [Epoch 61/200] [D loss: 0.150271] [G loss: 2.494723] [Elapsed time: 817.76s]
# [Epoch 62/200] [D loss: 0.184197] [G loss: 2.891073] [Elapsed time: 831.20s]
# [Epoch 63/200] [D loss: 0.065709] [G loss: 3.714882] [Elapsed time: 845.03s]
# [Epoch 64/200] [D loss: 0.366440] [G loss: 6.382102] [Elapsed time: 858.70s]
# [Epoch 65/200] [D loss: 0.332224] [G loss: 5.225374] [Elapsed time: 872.81s]
# [Epoch 66/200] [D loss: 0.236224] [G loss: 2.501487] [Elapsed time: 886.68s]
# [Epoch 67/200] [D loss: 0.097856] [G loss: 3.190082] [Elapsed time: 900.52s]
# [Epoch 68/200] [D loss: 0.108523] [G loss: 3.625573] [Elapsed time: 914.01s]
# [Epoch 69/200] [D loss: 0.097323] [G loss: 3.672597] [Elapsed time: 927.86s]
# [Epoch 70/200] [D loss: 0.191438] [G loss: 2.358246] [Elapsed time: 941.65s]
# [Epoch 71/200] [D loss: 0.157588] [G loss: 2.178713] [Elapsed time: 955.38s]
# [Epoch 72/200] [D loss: 0.124104] [G loss: 3.649027] [Elapsed time: 969.30s]
# [Epoch 73/200] [D loss: 0.836947] [G loss: 11.301134] [Elapsed time: 983.07s]
# [Epoch 74/200] [D loss: 0.064421] [G loss: 3.096515] [Elapsed time: 997.33s]
# [Epoch 75/200] [D loss: 0.151638] [G loss: 2.272236] [Elapsed time: 1011.42s]
# [Epoch 76/200] [D loss: 0.088877] [G loss: 3.439463] [Elapsed time: 1025.50s]
# [Epoch 77/200] [D loss: 0.071920] [G loss: 2.867338] [Elapsed time: 1039.18s]
# [Epoch 78/200] [D loss: 0.118649] [G loss: 2.975673] [Elapsed time: 1053.04s]
# [Epoch 79/200] [D loss: 0.101795] [G loss: 2.750700] [Elapsed time: 1066.95s]
# [Epoch 80/200] [D loss: 0.134814] [G loss: 2.316444] [Elapsed time: 1081.57s]
# [Epoch 81/200] [D loss: 0.123646] [G loss: 2.480938] [Elapsed time: 1095.82s]
# [Epoch 82/200] [D loss: 0.135026] [G loss: 3.245517] [Elapsed time: 1110.22s]
# [Epoch 83/200] [D loss: 0.142583] [G loss: 3.047660] [Elapsed time: 1124.29s]
# [Epoch 84/200] [D loss: 0.200202] [G loss: 2.789588] [Elapsed time: 1138.44s]
# [Epoch 85/200] [D loss: 0.107540] [G loss: 3.920578] [Elapsed time: 1152.24s]
# [Epoch 86/200] [D loss: 0.123734] [G loss: 3.518759] [Elapsed time: 1165.97s]
# [Epoch 87/200] [D loss: 0.267421] [G loss: 5.145612] [Elapsed time: 1179.68s]
# [Epoch 88/200] [D loss: 0.101337] [G loss: 2.991814] [Elapsed time: 1193.23s]
# [Epoch 89/200] [D loss: 0.075944] [G loss: 4.355514] [Elapsed time: 1206.46s]
# [Epoch 90/200] [D loss: 0.180670] [G loss: 4.110130] [Elapsed time: 1219.64s]
# [Epoch 91/200] [D loss: 0.148773] [G loss: 2.684165] [Elapsed time: 1233.01s]
# [Epoch 92/200] [D loss: 0.127141] [G loss: 2.800838] [Elapsed time: 1246.31s]
# [Epoch 93/200] [D loss: 0.124592] [G loss: 2.743192] [Elapsed time: 1260.11s]
# [Epoch 94/200] [D loss: 0.236562] [G loss: 1.878230] [Elapsed time: 1273.78s]
# [Epoch 95/200] [D loss: 0.126071] [G loss: 2.275409] [Elapsed time: 1287.32s]
# [Epoch 96/200] [D loss: 0.155486] [G loss: 2.108795] [Elapsed time: 1300.62s]
# [Epoch 97/200] [D loss: 0.180256] [G loss: 4.035494] [Elapsed time: 1313.60s]
# [Epoch 98/200] [D loss: 0.227215] [G loss: 4.109396] [Elapsed time: 1326.60s]
# [Epoch 99/200] [D loss: 0.154723] [G loss: 2.831154] [Elapsed time: 1339.59s]
# [Epoch 100/200] [D loss: 0.196602] [G loss: 4.117005] [Elapsed time: 1352.71s]
# [Epoch 101/200] [D loss: 0.211379] [G loss: 1.717267] [Elapsed time: 1365.65s]
# [Epoch 102/200] [D loss: 0.069651] [G loss: 2.844669] [Elapsed time: 1378.69s]
# [Epoch 103/200] [D loss: 0.177950] [G loss: 1.873442] [Elapsed time: 1391.66s]
# [Epoch 104/200] [D loss: 0.144339] [G loss: 2.758048] [Elapsed time: 1404.62s]
# [Epoch 105/200] [D loss: 0.053854] [G loss: 3.336043] [Elapsed time: 1417.57s]
# [Epoch 106/200] [D loss: 0.240190] [G loss: 2.959162] [Elapsed time: 1430.73s]
# [Epoch 107/200] [D loss: 0.261499] [G loss: 3.087918] [Elapsed time: 1443.78s]
# [Epoch 108/200] [D loss: 0.172669] [G loss: 2.689194] [Elapsed time: 1456.62s]
# [Epoch 109/200] [D loss: 0.330345] [G loss: 6.346256] [Elapsed time: 1469.57s]
# [Epoch 110/200] [D loss: 0.164071] [G loss: 1.919645] [Elapsed time: 1482.44s]
# [Epoch 111/200] [D loss: 0.162076] [G loss: 2.145525] [Elapsed time: 1495.51s]
# [Epoch 112/200] [D loss: 0.273021] [G loss: 2.219238] [Elapsed time: 1508.52s]
# [Epoch 113/200] [D loss: 0.155338] [G loss: 2.355662] [Elapsed time: 1521.51s]
# [Epoch 114/200] [D loss: 0.096988] [G loss: 3.030424] [Elapsed time: 1534.49s]
# [Epoch 115/200] [D loss: 0.190866] [G loss: 2.160914] [Elapsed time: 1547.35s]
# [Epoch 116/200] [D loss: 0.231547] [G loss: 1.923008] [Elapsed time: 1560.35s]
# [Epoch 117/200] [D loss: 0.118999] [G loss: 3.984318] [Elapsed time: 1573.27s]
# [Epoch 118/200] [D loss: 0.217097] [G loss: 2.126078] [Elapsed time: 1586.32s]
# [Epoch 119/200] [D loss: 0.215119] [G loss: 2.430696] [Elapsed time: 1599.32s]
# [Epoch 120/200] [D loss: 0.275409] [G loss: 1.653112] [Elapsed time: 1612.22s]
# [Epoch 121/200] [D loss: 0.165736] [G loss: 1.837086] [Elapsed time: 1625.32s]
# [Epoch 122/200] [D loss: 0.228851] [G loss: 2.664267] [Elapsed time: 1638.32s]
# [Epoch 123/200] [D loss: 0.150861] [G loss: 2.302030] [Elapsed time: 1651.29s]
# [Epoch 124/200] [D loss: 0.389522] [G loss: 4.816077] [Elapsed time: 1664.19s]
# [Epoch 125/200] [D loss: 0.297112] [G loss: 1.651833] [Elapsed time: 1677.30s]
# [Epoch 126/200] [D loss: 0.148206] [G loss: 2.846272] [Elapsed time: 1690.20s]
# [Epoch 127/200] [D loss: 0.189497] [G loss: 2.146804] [Elapsed time: 1703.06s]
# [Epoch 128/200] [D loss: 0.152549] [G loss: 3.216312] [Elapsed time: 1715.88s]
# [Epoch 129/200] [D loss: 0.201274] [G loss: 3.339652] [Elapsed time: 1728.79s]
# [Epoch 130/200] [D loss: 0.176320] [G loss: 1.969015] [Elapsed time: 1741.83s]
# [Epoch 131/200] [D loss: 0.263404] [G loss: 3.241963] [Elapsed time: 1754.77s]
# [Epoch 132/200] [D loss: 0.202345] [G loss: 2.176458] [Elapsed time: 1767.50s]
# [Epoch 133/200] [D loss: 0.292727] [G loss: 3.209682] [Elapsed time: 1780.35s]
# [Epoch 134/200] [D loss: 0.100434] [G loss: 3.077892] [Elapsed time: 1793.19s]
# [Epoch 135/200] [D loss: 0.184807] [G loss: 3.027042] [Elapsed time: 1806.19s]
# [Epoch 136/200] [D loss: 0.192188] [G loss: 1.593754] [Elapsed time: 1819.08s]
# [Epoch 137/200] [D loss: 0.110597] [G loss: 3.200911] [Elapsed time: 1832.11s]
# [Epoch 138/200] [D loss: 0.197925] [G loss: 2.530878] [Elapsed time: 1844.94s]
# [Epoch 139/200] [D loss: 0.138687] [G loss: 2.763186] [Elapsed time: 1857.90s]
# [Epoch 140/200] [D loss: 0.171212] [G loss: 2.109132] [Elapsed time: 1870.73s]
# [Epoch 141/200] [D loss: 0.202086] [G loss: 2.660858] [Elapsed time: 1883.44s]
# [Epoch 142/200] [D loss: 0.150640] [G loss: 2.807850] [Elapsed time: 1896.34s]
# [Epoch 143/200] [D loss: 0.130386] [G loss: 2.407938] [Elapsed time: 1909.38s]
# [Epoch 144/200] [D loss: 0.209497] [G loss: 2.699568] [Elapsed time: 1922.24s]
# [Epoch 145/200] [D loss: 0.176658] [G loss: 3.810553] [Elapsed time: 1935.01s]
# [Epoch 146/200] [D loss: 0.142112] [G loss: 2.320451] [Elapsed time: 1947.86s]
# [Epoch 147/200] [D loss: 0.150228] [G loss: 3.180416] [Elapsed time: 1960.60s]
# [Epoch 148/200] [D loss: 0.235149] [G loss: 2.988750] [Elapsed time: 1973.53s]
# [Epoch 149/200] [D loss: 0.180214] [G loss: 2.103580] [Elapsed time: 1986.41s]
# [Epoch 150/200] [D loss: 0.303783] [G loss: 1.229919] [Elapsed time: 1999.02s]
# [Epoch 151/200] [D loss: 0.156406] [G loss: 3.850565] [Elapsed time: 2011.85s]
# [Epoch 152/200] [D loss: 0.137676] [G loss: 3.925073] [Elapsed time: 2024.68s]
# [Epoch 153/200] [D loss: 0.255922] [G loss: 4.392951] [Elapsed time: 2037.53s]
# [Epoch 154/200] [D loss: 0.172178] [G loss: 4.536053] [Elapsed time: 2050.37s]
# [Epoch 155/200] [D loss: 0.173588] [G loss: 3.375519] [Elapsed time: 2063.06s]
# [Epoch 156/200] [D loss: 0.278739] [G loss: 3.749439] [Elapsed time: 2075.94s]
# [Epoch 157/200] [D loss: 0.238742] [G loss: 4.822608] [Elapsed time: 2088.76s]
# [Epoch 158/200] [D loss: 0.188547] [G loss: 2.941819] [Elapsed time: 2101.50s]
# [Epoch 159/200] [D loss: 0.119050] [G loss: 3.081698] [Elapsed time: 2114.25s]
# [Epoch 160/200] [D loss: 0.173733] [G loss: 2.220255] [Elapsed time: 2127.08s]
# [Epoch 161/200] [D loss: 0.056955] [G loss: 3.182358] [Elapsed time: 2139.76s]
# [Epoch 162/200] [D loss: 0.241544] [G loss: 4.976267] [Elapsed time: 2152.67s]
# [Epoch 163/200] [D loss: 0.077851] [G loss: 3.127359] [Elapsed time: 2165.58s]
# [Epoch 164/200] [D loss: 0.170789] [G loss: 2.377809] [Elapsed time: 2178.35s]
# [Epoch 165/200] [D loss: 0.162731] [G loss: 1.954517] [Elapsed time: 2191.22s]
# [Epoch 166/200] [D loss: 0.234708] [G loss: 2.110397] [Elapsed time: 2204.18s]
# [Epoch 167/200] [D loss: 0.123916] [G loss: 3.792036] [Elapsed time: 2217.44s]
# [Epoch 168/200] [D loss: 0.217869] [G loss: 2.826017] [Elapsed time: 2230.59s]
# [Epoch 169/200] [D loss: 0.284810] [G loss: 3.046438] [Elapsed time: 2243.69s]
# [Epoch 170/200] [D loss: 0.201273] [G loss: 3.092971] [Elapsed time: 2256.85s]
# [Epoch 171/200] [D loss: 0.159459] [G loss: 3.486506] [Elapsed time: 2269.73s]
# [Epoch 172/200] [D loss: 0.223997] [G loss: 2.699597] [Elapsed time: 2282.40s]
# [Epoch 173/200] [D loss: 0.312320] [G loss: 3.601397] [Elapsed time: 2295.13s]
# [Epoch 174/200] [D loss: 0.137668] [G loss: 2.249095] [Elapsed time: 2307.99s]
# [Epoch 175/200] [D loss: 0.374575] [G loss: 5.526731] [Elapsed time: 2320.74s]
# [Epoch 176/200] [D loss: 0.168941] [G loss: 3.571907] [Elapsed time: 2333.56s]
# [Epoch 177/200] [D loss: 0.142977] [G loss: 2.512741] [Elapsed time: 2346.37s]
# [Epoch 178/200] [D loss: 0.195851] [G loss: 3.760331] [Elapsed time: 2359.18s]
# [Epoch 179/200] [D loss: 0.195684] [G loss: 2.404037] [Elapsed time: 2372.03s]
# [Epoch 180/200] [D loss: 0.174813] [G loss: 3.861143] [Elapsed time: 2384.78s]
# [Epoch 181/200] [D loss: 0.285122] [G loss: 3.515740] [Elapsed time: 2397.74s]
# [Epoch 182/200] [D loss: 0.258336] [G loss: 3.365117] [Elapsed time: 2410.52s]
# [Epoch 183/200] [D loss: 0.212635] [G loss: 2.574721] [Elapsed time: 2423.20s]
# [Epoch 184/200] [D loss: 0.436840] [G loss: 7.241201] [Elapsed time: 2435.86s]
# [Epoch 185/200] [D loss: 0.147307] [G loss: 2.947976] [Elapsed time: 2448.51s]
# [Epoch 186/200] [D loss: 0.198865] [G loss: 3.400264] [Elapsed time: 2461.29s]
# [Epoch 187/200] [D loss: 0.206167] [G loss: 2.728231] [Elapsed time: 2474.14s]
# [Epoch 188/200] [D loss: 0.167479] [G loss: 3.011483] [Elapsed time: 2486.96s]
# [Epoch 189/200] [D loss: 0.109863] [G loss: 3.230690] [Elapsed time: 2499.63s]
# [Epoch 190/200] [D loss: 0.161265] [G loss: 2.282898] [Elapsed time: 2512.51s]
# [Epoch 191/200] [D loss: 0.193598] [G loss: 2.496312] [Elapsed time: 2525.29s]
# [Epoch 192/200] [D loss: 0.172509] [G loss: 4.170778] [Elapsed time: 2537.97s]
# [Epoch 193/200] [D loss: 0.207592] [G loss: 3.313636] [Elapsed time: 2550.87s]
# [Epoch 194/200] [D loss: 0.211475] [G loss: 2.217471] [Elapsed time: 2563.66s]
# [Epoch 195/200] [D loss: 0.237074] [G loss: 1.722158] [Elapsed time: 2576.48s]
# [Epoch 196/200] [D loss: 0.221520] [G loss: 2.191928] [Elapsed time: 2589.13s]
# [Epoch 197/200] [D loss: 0.223774] [G loss: 1.990800] [Elapsed time: 2601.85s]
# [Epoch 198/200] [D loss: 0.307374] [G loss: 1.210797] [Elapsed time: 2614.58s]
# [Epoch 199/200] [D loss: 0.136555] [G loss: 2.986265] [Elapsed time: 2627.38s]

# %%
from IPython.display import Image

Image('92000.png')
